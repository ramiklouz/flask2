# %%
import flask

# %%
from flask import Flask
app = Flask(__name__)
@app.route("/")
def hello():
    return "hello world!"

# %%
# !curl http://localhost:5000/

# %%
from flask import Flask
app = Flask(__name__)
@app.route("/")
def hello():
    return render_template('index.html')
app.run()
app.run(host='0.0.0.0', port=6000)

# %%
from flask import Flask render_template
app = Flask(__name__)
@app.route("/")
def hello():
    return render_template('regex front-end\index.html')
app.run()
app.run(host='0.0.0.0', port=6000)

# %%
from flask import Flask render_template
app = Flask(__name__)
@app.route("/")
def hello():
    return render_template('regex front-end\index.html')
app.run()
app.run(host='0.0.0.0', port=6000)

# %%
from flask import Flask
app = Flask(__name__)
@app.route("/")
def hello():
    return "hello world!"
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask render_template
app = Flask(__name__)
@app.route("/")
def hello():
    return render_template('regex front-end\index.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask
app = Flask(__name__)
@app.route("/")
def hello():
    return ('regex front-end\index.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask
app = Flask(__name__)
@app.route("/")
def hello():
    return ('regex front-end\index.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
set FLASK_DEBUG=1

# %%
from flask import Flask
app = Flask(__name__)
app.debug = True
@app.route("/")
def hello():
    return ('regex front-end\index.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask
app = Flask(__name__)
app.debug = True
@app.route("/")
def hello():
    return ('regex front-end\index.html')
app.run()
app.run(host='0.0.0.0', port=5000)
        
if __name__ == '__main__':
    app.run(debug=true)

# %%
from flask import Flask
app = Flask(__name__)
app.debug = True
@app.route("/")
def index():
    with open('index.html', 'r') as file:
        return file.read()
app.run()
app.run(host='0.0.0.0', port=5000)
        
if __name__ == '__main__':
    app.run(debug=true)

# %%
# %tb

# %%
from flask import Flask 
app = Flask(__name__)
@app.route("/")
@app.route('/')
def index():
    with open('regex front-end\REGEX.html', 'r') as file:
        return file.read()

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory
app = Flask(__name__)
@app.route("/")
@app.route('/')
def index():
    
        return send_from_directory('templates', 'regex front-end\REGEX.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory
app = Flask(__name__)
@app.route("/")
@app.route('/')
def index():
    
        return send_from_directory('templates', 'REGEX.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory
app = Flask(__name__)
@app.route("/")

def index():
        return send_from_directory('templates', 'REGEX.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory
app = Flask(__name__)
@app.route("/")

def index():
        return send_from_directory('templates', 'REGEX.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory
app = Flask(__name__)
@app.route("/")

def index():
        return send_from_directory('templates', 'REGEX.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask,  render_template
 
app = Flask(__name__,template_folder='templates', static_folder='static')
@app.route("/")

def index():
    return render_template('index.html')
 
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask,  render_template
 
app = Flask(__name__,template_folder='templates', static_folder='static')
@app.route("/")

def index():
    return render_template('REGEX.html')
 
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask,  render_template
 
app = Flask(__name__,template_folder='templates', static_folder='static')
@app.route("/")

def index():
    return render_template('REGEX.html')
 
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory
app = Flask(__name__)
@app.route("/")

def index():
        return send_from_directory('templates', 'REGEX.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory
app = Flask(__name__)
@app.route("/")

def index():
        return send_from_directory('templates', 'REGEX.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
G

# %%
from flask import Flask,  render_template
 
app = Flask(__name__,template_folder='templates', static_folder='static')
@app.route("/")

def index():
    return render_template('REGEX.html')
 
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
# %pdb on

# %%
from flask import Flask,  render_template
 
app = Flask(__name__,template_folder='templates', static_folder='static')
@app.route("/")

def index():
    return render_template('REGEX.html')
 
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask,render_template,url_for
 
app = Flask(__name__,template_folder='templates', static_folder='static')
@app.route("/")

def index():
    return render_template('REGEX.html')
 
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask,render_template,url_for
 
app = Flask(__name__,template_folder='templates', static_folder='static')
@app.route("/")

def index():
    return render_template('REGEX.html')
 
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask,render_template,url_for
 
app = Flask(__name__,template_folder='templates', static_folder='static')
@app.route("/")

def index():
    return render_template('REGEX.html',posts=posts)
 
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")

def index():
        return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")

def index():
        return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")

def index():
        return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")

def index():
        return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")

def index():
        return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")

import PyPDF2
from PyPDF2 import PdfReader
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]

verify_text(page.extract_text())

def index():
  output_of_python_code = verify_text(page.extract_text())
        
  return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")

import PyPDF2
from PyPDF2 import PdfReader
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]

verify_text(page.extract_text())

def index():
  output_of_python_code = verify_text(page.extract_text())
        
  return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]



def index():
  output_of_python_code = verify_text(page.extract_text())
        
  return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]



def index():
  @app.route('/result',methods = ['POST', 'GET']
  output_of_python_code = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]



def index():
  @app.route('/result',methods = ['POST', 'GET']
  output_of_python_code = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]



def index():
  @app.route('/result',methods = ['POST', 'GET']
  output_of_python_code = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]



def index():
  @app.route('/result',methods = ['POST', 'GET'])
  output_of_python_code = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]



def index():
  @app.route('/result',methods = ['POST', 'GET'])
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/result',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/r',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/r',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/")


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/result',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/result',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
index.run()
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
index.run()
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
text1="Klouzrami 20-02-2000 ramiklouz@gmail.com 97-170-989 4586-8795-6225-5555 Beyni.bilel 21-09-2000 beynibilel@gmail.com 58-170-989 0554-5555-6005-5555 "
f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def index():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')

app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def main():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def main():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def main():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def main():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def main():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def main():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  if request.method == 'POST':    
   return send_from_directory('templates', 'main.html',output=output)
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def main():
  return render_template('main.html')
  
  output = verify_text(page.extract_text())
  
  return send_from_directory('templates', 'main.html',output=output)
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()
from PyPDF2 import PdfReader

reader = PdfReader("cd2.pdf")
page = reader.pages[0]


@app.route('/',methods = ['POST', 'GET'])
def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
conda install flask

# %%
conda install pypdf2

# %%
conda install redex

# %%
conda install regex

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

#f=open('test1.txt','r')
#text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

#f=open('test1.txt','r')
#text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/r',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/r',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/result',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

#@app.route('/pdf')
#def pdf():
 #   return send_from_directory('static', 'cd2.pdf', test=True)
#reader = PdfReader("cd2.pdf")
#page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
conda install nbconvert==5.4.1

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    #person = re.search("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #if person :
    # person1 = re.findall("([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}|[a-z]{1,2}[ -\']{1}[A-Z]{1}[a-z]{1,30}){2,5}",text)
    #print("owner:",person1)
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
conda install nbconvert==5.4.1

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
conda install --upgrade --user nbconvert

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  return send_from_directory('templates', 'main.html')
  if request.method == "POST":
    dp = request.form["file"]
    output = verify_text(page.extract_text())
    return render_template('main.html',output=output)
#f=open('test1.txt','r')
#text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  return send_from_directory('templates', 'main.html')
  if request.method == "POST":
    dp = request.form["file"]
    output = verify_text(page.extract_text())
    return render_template('main.html',output=output)
#f=open('test1.txt','r')
#text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)



#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/Uploadpdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)



#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/Uploadpdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  

  return render_template('main.html')
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

app.static_folder = 'static'
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  

  return render_template('main.html')
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

@app.route('/static/main')
def serve_static(main):
    return send_static_file(main)
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  

  return render_template('main.html')
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
conda install ipywidgets

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

@app.route('/static/main')
def serve_static(main):
    return send_static_file(main)
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])

def main():
  return render_template('main.html')
  return send_from_directory('templates', 'main.html')


@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/",methods = ['POST', 'GET'])

@app.route('/static/main')
def serve_static(main):
    return send_static_file(main)
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])

def main():
  return render_template('main.html')
  #return send_from_directory('templates', 'main.html')


@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/",methods = ['POST', 'GET'])

@app.route('/static/main')
def serve_static(main):
    return send_static_file(main)
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])

def main():
  return render_template('main.html')
  #return send_from_directory('templates', 'main.html')


@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/",methods = ['POST', 'GET'])

@app.route('/static/main')
def serve_static(main):
    return send_static_file(main)
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])

def main():
  return render_template('main.html')
  #return send_from_directory('templates', 'main.html')


@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/",methods = ['POST', 'GET'])

@app.route('/static/main')
def serve_static(main):
    return send_static_file(main)
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])

def main():
  return render_template('main.html')
  #return send_from_directory('templates', 'main.html')


@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
@app.route("/",methods = ['POST', 'GET'])

@app.route('/static/main')
def serve_static(main):
    return send_static_file(main)
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])

def main():
  return render_template('main.html')
  #return send_from_directory('templates', 'main.html')


@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
    return render_template("index.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
    return render_template("index.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
     return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
    return render_template("index.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    render_template("main.html", result=verify_text(text))
#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
    page = pdf.getPage(0)
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)
#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
    page = pdf.getPage(0)
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)
#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
# %load_ext autoreload

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
    page = pdf.getPage(0)
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)
#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
    page = pdf.getPage(0)
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)
#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
    page = pdf.getPage(0)
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)
#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    render_template("main.html", result=verify_text(text))
#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
   
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
   
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
   
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
   
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
   
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
   
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

app.debug = True

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
conda install watchdog

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

app.debug = True

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
exit

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

app.debug = True

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

#app.debug = True

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

#app.debug = True

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

#app.debug = True

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
def main():
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')


#f=open('test1.txt','r')
#text1=f.read()

#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def Uploadpdf():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return result

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')

def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])


def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
reader = PdfReader("cd2.pdf")
page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])
app.debug = True

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\Lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template
app = Flask(__name__)
#@app.route("/",methods = ['POST', 'GET'])
app.debug = True

def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)

f=open('test1.txt','r')
text1=f.read()

@app.route('/pdf')
def pdf():
    return send_from_directory('static', 'cd2.pdf', test=True)
    reader = PdfReader("cd2.pdf")
    page = reader.pages[0]

@app.route('/',methods = ['POST', 'GET'])


def main():
  
  
  output = verify_text(page.extract_text())
  return render_template('main.html',output=output)
  return send_from_directory('templates', 'main.html')
def login():
    return render_template('login.html')
@app.route('/login',methods = ['POST', 'GET'])

@app.route('/login')
def login():
    return render_template('login.html')
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\Lenovo\anaconda3\envs\notebook\lib\site-packages\IPython\core\interactiveshell.py:3450: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
   
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
   
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
app.debug = True
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.19:5000/ (Press CTRL+C to quit)

# %%
import re
import PyPDF2
from PyPDF2 import PdfReader
from flask import Flask, send_from_directory,url_for,render_template,request
app = Flask(__name__)
app.debug = True
#the regex function
def verify_text(text):
    credit=re.search("\d{4}-\d{4}-\d{4}",text)
    phone_number=re.search("\d{2}\s\d{3}\s\d{3}",text)
    email=re.search("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}", text)
    date = re.search("(\d{2}-\d{1,2}-\d{4})",text)
    
    if date :
     date1=re.findall("(\d{2}-\d{1,2}-\d{4})",text)
     print("date of creation:",date1)
    if email :
     email1=re.findall("[\w._%+-]{1,20}@[\w.-]{2,20}.[A-Z,a-z]{2,3}",text)
     print("Email:",email1)
    if credit:
     credit_card1=re.findall("\d{4}-\d{4}-\d{4}",text)
     print("credit card:",credit_card1)
    if phone_number:
     phn1=re.findall("\d{2}\s\d{3}\s\d{3}",text)
     print("phone number:",phn1)
@app.route('/',methods = ['POST', 'GET'])
def main():
    return send_from_directory('templates', 'main.html')
    return render_template('main.html')
    return render_template("main.html", result=result)
#f=open('test1.txt','r')
#text1=f.read()
#getting pdf from the input file then converting it to a txt file.
@app.route('/pdf', methods=['POST'])
def pdfreg():
    pdffile = request.files['file']
    pdf = PdfReader(pdffile.stream)
   
    page = pdf.getPage(0)
   
    text = page.extractText()
    result = verify_text(text)
    return render_template("main.html", result=result)

#to go to the login page 

@app.route('/login',methods = ['POST'])


def login():
    return render_template('login.html')
#to go to the sign up page 
@app.route('/signup')
def signup():
    return render_template('signup.html')
app.run()
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\Lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
